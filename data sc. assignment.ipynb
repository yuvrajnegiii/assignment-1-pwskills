# %%
                                                                             ASSIGNMENT - 1
    
    Q1- Who developed python programming language?
    Ans-Python was created by Guido van Rossum , and first released on february 20 , 1991.
    
    Q2- Which type of programming does python support?
    Ans- Python is a multi-paradigm programming language. Object Oriented Programming and Structured Programming are fully supported , and many of their features support functional 
         programming and aspect-oriented programming (including meta programming and meta objects).
        
    Q3- Is python case sensitive while dealing with identifiers?
    Ans-YES, Python is a case sensitive language , i.e , it treats uppercase and lowecase charachters differently. This applies to identifiers too. We should avoid using the same name 
        with different cases while naming identifiers. It is always good to use names that are more easily understood.
        
    Q4- What is the correct extension of the python file?
    Ans-Python is a widely used programming or coding language used for different purposes. The extensions for Python files - (.py , .pyi) . 
    
    Q5- Is python code compiled or interpreted?
    Ans- Python is an interpreted language , which means the source code of python program is converted into bytecodes that is then executed by the python virtual machine .
    
    Q6- Name a few blocks of code used to define in python languages?
    Ans- A python program is constructed from code blocks. A block is a piece of python program text is executed as a unit. the following are blocks: 
         a) a module
         b) a function body 
         c) a class defintion
            
    Q7- State a charachter used to give single-line comments in python?
    Ans- We can write a single "#" charachter before any statement or line of code.
        
    Q8- Mention functions which can help us to find the version of python that we are currently working on?
    Ans- The function sys.version can help us to find the version of python that we are currently working on.
        
    Q9- Python supports the creation of anonymous functions at runtime, using a construct called?
    Ans- Python uses construct called ("lambda") which supports the creation of anonymous functions at runtime.
    
    Q10- What does pip stands for python?
    Ans- pip stands for " preferred installer program " for python.
    
    Q11- Mention a few built-in functions in python?
    Ans- Python has a set of built-in fuctions among them some are mentioned below:
         
            FUNCTION                                DESCRIPTION
            
            
            dict()                                  Returns a dictionary (ARRAY)
            
            float()                                 Returns a floating point number
            
            list()                                  Returns a list
            
            slice()                                 Returns a slice object
            
            set()                                   Returns a new set object
            
            str()                                   Returns a string
            
            tuple()                                 Returns a tuple
            
            sorted()                                Returns a sorted list
            
    
    Q12- What is the maximum possible length of an identifier in Python?
    Ans- An identifier can have a maximum length of "79" characters in python.
    
    Q13- What are the benefits of using Python?
    Ans- Benefits of using python are:
         1. simple to use and understand
         2. free and open source
         3. productivity has increased
         4. interpreted language
         5. extensive libraries
         6. portability
         7. supportive community
         8. dynamically typed
        
    Q14- How is memory managed in Python?
    Ans- Memory management in python involves a private heap containing all python objects and data structures . The management of this private heap is ensured internally by the 
         ython memory manager.
        
    Q15- How to install python on windows and set path variables?
    Ans- The complete path of python.exe can be added by:
        
        1. Right click This PC and going to properties.
        2. Clicking on the Advanced system settings in the menu on the left.
        3. Clicking the Envoirnment Variables button on the bottom right.
        4. In the system variable section , selecting path variable and clicking on edit. The next screen will show all the directories that are currently a part of the path variable.
        5.Clicking on new and entering Python's install directory.
        
    Q16. Is identation required in python?
    Ans- Identation refers to the space at the beginning of a code line. Where in other programming languages the identation in code is for readibility only. Identation in Python is 
         very important. Python uses identation to indicate block of codes.
